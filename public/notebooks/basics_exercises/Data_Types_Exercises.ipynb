# %% [markdown]
# # Python Data Types - Practice Exercises
#
# Complete the exercises below to check your understanding of Python's basic data types: Numbers, Strings, and Booleans.

# %% [markdown]
# ## Exercise 1: Regular vs Floor Division
#
# **Task:** Write a Python statement to divide `15` by `4` using regular division, and then using floor (integer) division. Print the result and type of each.

# %%
# TODO: Perform regular division and floor division of 15 by 4

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# reg_res = 15 / 4
# floor_res = 15 // 4
# print("Regular:", reg_res, type(reg_res))
# print("Floor:", floor_res, type(floor_res))
# ```
# </details>

# %% [markdown]
# ## Exercise 2: Floating-Point Precision Comparisons
#
# **Task:** Write code to verify if `0.1 + 0.2` equals `0.3`, and if `0.25 + 0.5` equals `0.75`. Print both evaluations.

# %%
# TODO: Write equality checks for both float expressions

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# check1 = (0.1 + 0.2 == 0.3)
# check2 = (0.25 + 0.5 == 0.75)
# print("Sharmas 0.1 + 0.2 equal 0.3?", check1)
# print("Sharmas 0.25 + 0.5 equal 0.75?", check2)
# ```
# </details>

# %% [markdown]
# ## Exercise 3: Integer Caching (Object IDs)
#
# **Task:** Initialize `a = 256` and `b = 256`. Then initialize `x = 257` and `y = 257`. Write code to verify if `a` and `b` point to the same memory location, and if `x` and `y` point to the same location using the `is` operator.

# %%
# TODO: Create small and large integer references and compare using 'is'

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# a = 256
# b = 256
# print("Are small integers cached together?", a is b) # True
#
# x = 257
# y = 257
# print("Are larger integers cached together?", x is y) # False
# ```
# </details>

# %% [markdown]
# ## Exercise 4: String Formatting and Underscores
#
# **Task:** The following code contains errors. Fix the representation of the large number and mismatched quotes so it runs cleanly.

# %%
# TODO: Fix the number representation and string quotes
population = 1,200,000
message = 'The population of the city is " + str(population)

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# population = 1_200_000
# message = "The population of the city is " + str(population)
# print(message)
# ```
# </details>

# %% [markdown]
# ## Exercise 5: String Length & Concatenation
#
# **Task:** Combine the two strings `part1 = "AI Development"` and `part2 = "with Python"` with a space in between. Then, calculate and print the total length of the combined string.

# %%
# TODO: Concatenate strings and find their total length

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# part1 = "AI Development"
# part2 = "with Python"
# combined = part1 + " " + part2
# print("Combined:", combined)
# print("Length:", len(combined))
# ```
# </details>

# %% [markdown]
# ## Exercise 6: Boolean Comparisons
#
# **Task:** Fix the capitalization error and the comparison operator in the code below so it checks if `points` is exactly equal to `100`.

# %%
# TODO: Fix capitalization of boolean and equality operator
game_over = true
points = 100

if points = 100:
    print("Perfect score! Game over status:", game_over)

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# game_over = True
# points = 100
#
# if points == 100:
#     print("Perfect score! Game over status:", game_over)
# ```
# </details>
