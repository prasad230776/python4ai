# %% [markdown]
# # First Python File - Exercises
#
# Complete the following exercises to test your understanding of writing and running Python code. If you get stuck, click the dropdown to view the solution!

# %% [markdown]
# ## Exercise 1
#
# **Task:** Write a Python statement that prints the exact message: `I am writing my very first Python script!`

# %%
# TODO: Write a print statement to display the message

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# print("I am writing my very first Python script!")
# ```
# </details>

# %% [markdown]
# ## Exercise 2
#
# **Task:** Print the result of multiplying `12` by `12` directly within a `print()` statement (do not write it as a string; let Python perform the calculation).

# %%
# TODO: Write a print statement that calculates and displays 12 * 12

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# print(12 * 12)
# ```
# </details>

# %% [markdown]
# ## Exercise 3
#
# **Task:** Write code that outputs two separate lines of text:
# 1. The first line should say `Python for AI`.
# 2. The second line should say `Step by Step`.

# %%
# TODO: Output the two lines of text on separate lines

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# print("Python for AI")
# print("Step by Step")
# ```
# </details>
