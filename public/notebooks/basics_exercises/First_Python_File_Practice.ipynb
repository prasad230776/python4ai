# %% [markdown]
# # First Python File - Follow-Along Practice
#
# Use this notebook to practice the examples discussed in the course page for **First Python File**.

# %% [markdown]
# ## 1. Writing Your First Print Statements
#
# Run the cell below to print messages to the screen using the `print()` function.

# %%
print("Hello, World!")
print("I'm learning Python for AI")

# %% [markdown]
# ## 2. Experimenting with Print Statements
#
# Try changing the code and printing your own messages, such as your name.

# %%
print("Hello, World!")
print("I'm learning Python for AI")
print("My name is [Your Name]")
print("Today is a great day to code!")
