# %% [markdown]
# # Getting Started - Exercises
#
# Complete the exercises below to check your understanding of running files, managing environments, installing packages, and interactive coding.

# %% [markdown]
# ## Exercise 1: Customizing Print Outputs
#
# **Task:** Write a Python statement that prints your name and your primary goal for learning Python for AI on separate lines.

# %%
# TODO: Write print statements to display your details

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# print("Name: Siva Prasad")
# print("Goal: Building awesome agentic workflows!")
# ```
# </details>

# %% [markdown]
# ## Exercise 2: Debugging and Running Code
#
# **Task:** The code in the cell below has a syntax error. Correct the error so the script runs successfully.

# %%
# TODO: Fix this code block
print("Checking system settings...) # Missing closing quotes

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# print("Checking system settings...")
# ```
# </details>

# %% [markdown]
# ## Exercise 3: Package Verification
#
# **Task:** Write code to verify if the `numpy` package is installed in your current environment and print its version. (Hint: import `numpy` as `np` and print `np.__version__` or check exception handling).

# %%
# TODO: Try to import numpy and print its version. Handle potential ImportError.

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# try:
#     import numpy as np
#     print("NumPy is installed! Version:", np.__version__)
# except ImportError:
#     print("NumPy is not installed in the current virtual environment.")
# ```
# </details>
