# %% [markdown]
# # Getting Started - Follow-Along Practice
#
# Use this notebook to practice the concepts and code from the **Getting Started** section of the course, including your first Python file, packages, virtual environments, and interactive Python.

# %% [markdown]
# ## 1. Your First Program (`hello.py`)
#
# Let's practice the basic print statements used to verify your setup.

# %%
print("Hello, World!")
print("I'm learning Python for AI!")

# %% [markdown]
# ## 2. Testing Python Packages & Import
#
# Once you have activated your virtual environment and installed packages using `pip install`, you can verify the imports in your code.

# %%
# Example of importing a standard library module to inspect current environment info
import sys
print("Python version:", sys.version)
print("Interpreter Path:", sys.executable)

# %% [markdown]
# ## 3. Interactive Python Superpowers
#
# In Interactive Python mode, variables persist in memory. Run the cells below sequentially (or using `Shift + Enter` in your editor) to see it in action.

# %%
# Step 1: Create variables
course_name = "Python for AI"
numbers = [10, 20, 30, 40]

# %%
# Step 2: Use variables in a separate execution block
print(f"Welcome to {course_name}!")
print("Sum of numbers:", sum(numbers))
