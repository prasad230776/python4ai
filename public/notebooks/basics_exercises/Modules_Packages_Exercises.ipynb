# %% [markdown]
# # Python Modules and Packages - Practice Exercises
#
# Complete the exercises below to check your understanding of Python modules and packages.

# %% [markdown]
# #### Exercise 1: Standard Math Functions
#
# **Task:**
# 1. Import the built-in `math` module.
# 2. Calculate and print the square root of `144` using `math.sqrt()`.
# 3. Use `math.floor(3.7)` and print the result.

# %%
# TODO: Import math and calculate sqrt/floor values

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# import math
# print("Square root:", math.sqrt(144)) # 12.0
# print("Floor value:", math.floor(3.7)) # 3
# ```
# </details>

# %% [markdown]
# #### Exercise 2: Exponentiation using Specific Imports
#
# **Task:**
# 1. Import only the `pow` function directly from the `math` module.
# 2. Calculate $2^5$ using `pow(2, 5)` and print the result.

# %%
# TODO: Import pow and calculate power

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# from math import pow
# print("Result:", pow(2, 5)) # 32.0
# ```
# </details>

# %% [markdown]
# #### Exercise 3: Direct Execution Check
#
# **Task:** Write a simple script structure where:
# 1. You define a function `run_test()` that prints `"Running tests..."`.
# 2. Use `if __name__ == "__main__":` to call `run_test()` only when the script is run directly.

# %%
# TODO: Write function and __main__ condition check

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# def run_test():
#     print("Running tests...")
#
# if __name__ == "__main__":
#     run_test()
# ```
# </details>
