# %% [markdown]
# # Python Basics - Practice and Exercises
#
# Welcome! This notebook combines practice examples and exercises for the fundamental concepts of Python:
# - **Intro to Programming**: What programming is and its basic operations.
# - **Python Syntax**: Rules of writing Python code, including indentation.
# - **Python Errors**: How to read and fix common errors.
# - **Code Formatting**: Writing clean, readable code following PEP 8.
# - **Variables**: Storing, naming, and changing data.
# - **Comments**: Documenting your code.
#
# Run each practice cell using `Shift + Enter` to see how it works, and try to complete each exercise cell!

# %% [markdown]
# ## 1. Intro to Programming & Python Syntax
#
# ### Follow-Along Practice
# Below are examples showing how computers execute operations step-by-step and how Python enforces indentation.

# %%
# Basic programming operations
price = 100
tax = 8.25
total = price + tax
print("Total price:", total)

# Indentation defines structure in Python
temperature = 32
if temperature > 30:
    print("It's hot!")
    print("Turn on the AC.")

# %% [markdown]
# ### Exercise 1: Fixing Indentation
#
# **Task:** Fix the indentation in the code block below so it runs without throwing an `IndentationError`.

# %%
# TODO: Fix the indentation error
score = 95
if score > 90:
  print("A grade")      # Hint: Indentation should be consistent (typically 4 spaces)
    print("Perfect!")

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# score = 95
# if score > 90:
#     print("A grade")
#     print("Perfect!")
# ```
# </details>

# %% [markdown]
# ## 2. Python Errors & Code Formatting
#
# ### Follow-Along Practice
# Let's practice identifying where errors occur and learning PEP 8 formatting rules like spacing.

# %%
# PEP 8 standard formatting (Good spacing around operators)
a = 10 + 5
numbers = [1, 2, 3]

# Multiple lines for long strings
long_message = (
    "This is a clean way to format "
    "a very long string over multiple lines."
)
print(long_message)

# %% [markdown]
# ### Exercise 2: Debugging a Syntax Error
#
# **Task:** Fix the `SyntaxError` in the cell below so the print statement executes correctly.

# %%
# TODO: Fix the SyntaxError below
print("Welcome to Python for AI)

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# print("Welcome to Python for AI")
# ```
# </details>

# %% [markdown]
# ### Exercise 3: Formatting According to PEP 8
#
# **Task:** Reformat the following poorly spaced and formatted code block according to Python PEP 8 guidelines (use proper spacing around operators and after commas).

# %%
# TODO: Format this code according to PEP 8 standards
x=5+10
my_list=[1,2,3,4]
total_sum=x+sum(my_list)

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# x = 5 + 10
# my_list = [1, 2, 3, 4]
# total_sum = x + sum(my_list)
# ```
# </details>

# %% [markdown]
# ## 3. Variables
#
# ### Follow-Along Practice
# Variables are boxes that hold data. We can assign them, update them, and use them in computations.

# %%
# Storing different types of data
name = "Alice"
age = 25
is_student = True

# Changing/updating variables
score = 0
score = score + 10
score = score + 5
print(f"{name}'s score is: {score}")

# %% [markdown]
# ### Exercise 4: Variable Naming and snake_case
#
# **Task:** Fix the illegal variable names below so that they follow Python's standard `snake_case` convention and run without raising errors.

# %%
# TODO: Correct these illegal or non-standard variable names
user-name = "John"
1st_place_score = 100
userAge = 21

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# user_name = "John"
# first_place_score = 100
# user_age = 21
# ```
# </details>

# %% [markdown]
# ### Exercise 5: Modifying Variables
#
# **Task:** Initialize a variable `balance` to `100.0`. Simulate a deposit of `50.0` and a withdrawal of `30.0` by modifying the variable. Print the final balance.

# %%
# TODO: Initialize balance, perform operations, and print the result

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# balance = 100.0
# balance = balance + 50.0  # Deposit
# balance = balance - 30.0  # Withdrawal
# print("Final balance:", balance)
# ```
# </details>

# %% [markdown]
# ## 4. Comments
#
# ### Follow-Along Practice
# Comments are ignored by Python. They should explain *why* something is done, not *what* is done if it is obvious.

# %%
# Single-line comments start with a hash (#)
tax_rate = 0.0825  # CA sales tax is 8.25%

"""
This is a multi-line comment.
It is technically a triple-quoted string that isn't processed by Python,
which acts as a multi-line comment.
"""
print("Comments practice completed!")

# %% [markdown]
# ### Exercise 6: Writing Effective Comments
#
# **Task:** Add a single-line or multi-line comment to the following code explaining the *why* behind the constant `1.8` and `32` in the temperature conversion formula (Fahrenheit to Celsius).

# %%
celsius = 25
# TODO: Add a comment explaining the conversion math below
fahrenheit = (celsius * 1.8) + 32
print(f"{celsius}°C is equivalent to {fahrenheit}°F")

# %% [markdown]
# <details>
# <summary>💡 Click to see solution</summary>
#
# ```python
# celsius = 25
# # Multiply by 1.8 (equivalent to 9/5) and add 32 to convert to Fahrenheit
# fahrenheit = (celsius * 1.8) + 32
# print(f"{celsius}°C is equivalent to {fahrenheit}°F")
# ```
# </details>
