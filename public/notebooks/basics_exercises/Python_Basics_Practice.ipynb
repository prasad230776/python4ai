# %% [markdown]
# # Python Basics - Follow-Along Practice
#
# Use this notebook to practice the fundamental concepts of Python:
# - **Intro to Programming**: Basic operations
# - **Python Syntax**: Rules of writing Python code and indentation
# - **Python Errors**: Understanding and reading error tracebacks
# - **Code Formatting**: Basic PEP 8 readability standards
# - **Variables**: Creating and modifying variables
# - **Comments**: Documenting your code
#
# Run each cell using `Shift + Enter` to follow along.

# %% [markdown]
# ## 1. Intro to Programming & Python Syntax
#
# Basic programming operations and indentation rules.

# %%
# Basic programming operations
price = 100
tax = 8.25
total = price + tax
print("Total price:", total)

# Indentation defines structure in Python
temperature = 32
if temperature > 30:
    print("It's hot!")
    print("Turn on the AC.")

# %% [markdown]
# ## 2. Python Errors & Code Formatting
#
# Let's practice identifying where errors occur and learning PEP 8 formatting rules like spacing.

# %%
# PEP 8 standard formatting (Good spacing around operators)
a = 10 + 5
numbers = [1, 2, 3]

# Multiple lines for long strings
long_message = (
    "This is a clean way to format "
    "a very long string over multiple lines."
)
print(long_message)

# %% [markdown]
# ## 3. Variables
#
# Variables are boxes that hold data. We can assign them, update them, and use them in computations.

# %%
# Storing different types of data
name = "Alice"
age = 25
is_student = True

# Changing/updating variables
score = 0
score = score + 10
score = score + 5
print(f"{name}'s score is: {score}")

# %% [markdown]
# ## 4. Comments
#
# Comments are ignored by Python. They should explain *why* something is done, not *what* is done if it is obvious.

# %%
# Single-line comments start with a hash (#)
tax_rate = 0.0825  # CA sales tax is 8.25%

"""
This is a multi-line comment.
It is technically a triple-quoted string that isn't processed by Python,
which acts as a multi-line comment.
"""
print("Comments practice completed!")
